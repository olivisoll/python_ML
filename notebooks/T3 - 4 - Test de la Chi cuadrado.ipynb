# %%
from IPython.display import Image

# %%
Image(filename="resources/chi_cuadrado.png")

# %% [markdown]
# Test muy utilizado para comparar datos observados con datos esperados, asumiendo que los datos siguen una determinada hipótesis de distribución para calcularlos.

# %% [markdown]
# Se suele usar para:
#
# + Utilizarlo como elemento de **bondad de ajuste**. Comprobar si los datos son fiables y siguen una distribución conocida. Se observa si los datos que tenemos tienen cierto desvío comparados con los datos esperados.
#
# + Comparar dos variables X e Y:
#     - **Test de independencia**: nos ayuda a demostrar una posible relación o no entre 2 variables, un parámetro de entrada y uno de salida.
#     - **Test de la homogeneidad**: se usa para comparar si los datos son demasiado buenos para ser verdad, si están trucados o no.

# %% [markdown]
# La chi cuadrado necesita saber el **grado de libertad (df)**.

# %%
Image(filename="resources/chi_cuadrado2.png")

# %%
Image(filename="resources/chi_cuadrado3.png")
