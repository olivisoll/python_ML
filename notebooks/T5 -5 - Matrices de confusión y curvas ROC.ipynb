# %% [markdown]
# # Matrices de confusión

# %%
from IPython.display import Image
Image(filename="resources/matrices_confusion.png")

# %%
Image(filename="resources/matrices_confusion2.png")

# %% [markdown]
# Especifidad: tasa de verdaderos negativos

# %% [markdown]
# Un modelo correcto sería 100% sensible y 100% específico. Esto no suele ocurrir nunca.

# %%
Image(filename="resources/curvas_roc.png")

# %% [markdown]
# El peor caso es que la curva ROC quede en diagonal. Cuanto más levantada, mejor es la curva y mejor el modelo.
