# %% [markdown]
# # Validación cruzada o cross validation

# %%
from IPython.display import Image

# %%
Image(filename="resources/validacion_cruzada.png")

# %%
Image(filename="resources/validacion_cruzada_k_iteraciones.png")

# %% [markdown]
# Es más lento desde el punto de vista de la computación. Lo más común es utilizar una validación cruzada de 10 iteraciones

# %%
Image(filename="resources/validacion_cruzada_aleatoria.png")

# %% [markdown]
# Dividir aleatoriamente conjunto de datos de entranamiento y de prueba. La ventaja es que la división de datos no depende del número de iteraciones que se lleven a cabo, pero algunas muestras pueden haber quedado sin evaluar y otras que se evalúan demasiadas veces, los subconjuntos de prueba y entrenamiento pueden llegar a solaparse.

# %%
Image(filename="resources/validacion_cruzada_dejando_uno_fuera.png")

# %% [markdown]
# Implica separar los datos de forma que para cada iteración tengamos una sóla muestra para datos de prueba y el resto para datos de entrenamiento. La evaluación viene dada por el error, se tiende a tener un error muy bajo. A nivel computacional, mucha más costoso, tiene muchas iteraciones (N).
# La fórmula del error de este tipo de validación cruzada es ligeramente diferente a las anteriores.

# %%
Image(filename="resources/validacion_cruzada_k_iteraciones_ejemplo.png")
