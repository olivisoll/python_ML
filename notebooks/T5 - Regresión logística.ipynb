# %% [markdown]
# # Regresión logística

# %%
from IPython.display import Image

# %% [markdown]
# En la regresión lineal, la variable de salida siempre es una variable contínua (un número). Por tanto la regresión lineal es una buena elección si queremos predecir un valor numérico contínuo.
#
# Si la variable es discreta (clasificar en categorías, por ejemplo), necesitaremos un modelo de regresión logística. Es una variante de la regresión lineal, pero la variable de salida es un valor binario.

# %%
Image(filename="resources/regresion_logistica.png")

# %%
Image(filename="resources/regresion_logistica2.png")

# %% [markdown]
# Como podemos observar, ambas ecuaciones están relacionadas.

# %%
Image(filename="resources/regresion_logistica3.png")
