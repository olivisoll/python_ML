# %% [markdown]
# # Muestreo aleatorio y teorema central del límite

# %%
from IPython.display import Image
Image(filename="resources/muestreo_aleatorio.png")

# %%
Image(filename="resources/muestreo_aleatorio2.png")
