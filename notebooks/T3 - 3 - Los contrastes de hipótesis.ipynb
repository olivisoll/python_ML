# %%
from IPython.display import Image

# %%
Image(filename="resources/contraste_hipotesis.png")

# %% [markdown]
# **Hipótesis nula**: queremos que sea cierta

# %%
Image(filename="resources/contraste_hipotesis2.png")

# %% [markdown]
# # Cómo hacer un contraste de hipótesis paso a paso

# %%
Image(filename="resources/contraste_hipotesis3.png")

# %%
Image(filename="resources/contraste_hipotesis4.png")

# %%
Image(filename="resources/contraste_hipotesis6.png")

# %%
Image(filename="resources/contraste_hipotesis7.png")

# %% [markdown]
# ### Tipos de test

# %%
Image(filename="resources/contraste_hipotesis8.png")

# %%
Image(filename="resources/contrate_hipotesis9.png")

# %%
Image(filename="resources/contraste_hipotesis10.png")
